# %% [markdown]
# # Question 1
# 5 - int
# 5.0 - float
# 5 > 1 - boolean
# '5' - string
# 5 * 2 - int
# '5' * 2 - error
# '5' + '2' - string
# 5 / 2 - float
# 5 % 2 - int
# {5, 2, 1} - int
# 5 == 3 - boolean
# Pi (the number) - float

# %%
# Question 2 (a)
using System;

namespace ConsoleApp3
{
    class Program
    {
        static void Main(string[] args)
        {
            string s = "Supercalifragilisticexpialidocious";
            int sLength = s.Length;
            Console.WriteLine("The name " + s + " contains " + sLength   + "letters.");
        }
    }
}

# %%
# Question 2(b)

using System;

namespace ConsoleApp3
{
    class Program
    {
        static void Main(string[] args)
        {
            String phrase = "Supercalifragilisticexpialidocious";

            Console.WriteLine(phrase.Contains("ice"));
        }
    }
}

# %%
#Question 2(c)

using System;

namespace ConsoleApp3
{
    class Program
    {
        static void Main(string[] args)
        {
            string s = "Supercalifragilisticexpialidocious";
            int sLength = s.Length;
            Console.WriteLine("The name " + s + " contains " + sLength + "letters.");

            string s2 = "Honorificabilitudinitatibus";
            int s2Length = s2.Length;
            Console.WriteLine("The name " + s2 + " contains " + s2Length + "letters.");

            string s3 = "Bababadalgharaghtakamminarronnkonn";
            int s3Length = s3.Length;
            Console.WriteLine("The name " + s3 + " contains " + s3Length + "letters.");

# %%
#Question 2(d)
using System;
using System.Linq;

class Program
{
    static void Main()
    {
        string[] Names = new string[]
        {
            "Berlioz",
            "Borodin",
            "Brian",
            "Bartok",
            "Bellini",
            "Buxtehude",
            "Bernstein"
        };

        // Sort the names.
        var result = from name in Names
                     orderby name
                     select name;

        // Evaluate our query.
        foreach (string value in result)
        {
            Console.WriteLine(value);
        }
    }
}

# %%
# Question 3
using System;
public class TriangleArea
{
    public static void Main()
    {
        Console.Write("LENGTH 1:");
        double side1 = Convert.ToDouble(Console.ReadLine());
        Console.Write("lENGTH 2:");
        double side2 = Convert.ToDouble(Console.ReadLine());
        Console.Write("LENGTH 3:");
        double side3 = Convert.ToDouble(Console.ReadLine());

        double semiperimeter = (side1 + side2 + side3) / 2;
        double area = Math.Sqrt(semiperimeter * (semiperimeter - side1) * (semiperimeter - side2) * (semiperimeter - side3));
        Console.Write("Area of a the Triangle = " + area);
        
    }
}

# %%
#Question 4 - (help taken from stackflow)
using System;

namespace ConsoleApp4
{
    class Program
    {
        static void Main(string[] args)
        {
            int[] arr1 = new int[10];
            int[] arr2 = new int[10];
            int[] arr3 = new int[10];
            int i, j = 0, k = 0, n;
            
            Console.Write("Input the number of elements to be stored in the array :");
            n = Convert.ToInt32(Console.ReadLine());
            Console.Write("Input {0} elements in the array :", n);
            for (i = 0; i < n; i++)
            {
                Console.Write("element - {0} : ", i);
                arr1[i] = Convert.ToInt32(Console.ReadLine());
            }
            for (i = 0; i < n; i++)
            {
                if (arr1[i] % 2 == 0)
                {
                    arr2[j] = arr1[i];
                    j++;
                }
                else
                {
                    arr3[k] = arr1[i];
                    k++;
                }
            }
            Console.Write("\nThe Even elements are : \n");
            for (i = 0; i < j; i++)
            {
                Console.Write("{0} ", arr2[i]);
            }
            Console.Write("\nThe Odd elements are :\n");
            for (i = 0; i < k; i++)
            {
                Console.Write("{0} ", arr3[i]);
            }
            
        }
    }


}

# %%
#Question 5
using System;

class GFG
{

    //funct to find point
    static bool inside(int x1, int y1, int x2,
                          int y2, int x, int y)
    {
        if (x > x1 && x < x2 &&
            y > y1 && y < y2)
            return true;

        return false;
    }

    //main code
    public static void Main()
    {

        // function call
        if (inside(1, -1, 0, 0, 0, 0))
            Console.Write(true);
        else
            Console.Write(false);
    }


}

# %%
#Question 7

def bldcount():
  
    bldA = ['drake', 'John', 'Anthony', 'Peter']
    bldB = ["Stephen", "Gordon", "Sara"]
    bldAB =["Sunny"]
    bldO = ["Don", "Mercury", "june"]
    bldOO = ["Eve", "Eden", "Adolf"]

    print ("Number of patients with blood group A = ", len(bldA))
    print ("Number of patients with blood group B = ", len(bldB))
    print ("Number of patients with blood group AB = ", len(bldAB))
    print ("Number of patients with blood group O = ", len(bldO))
    print ("Number of patients with blood group OO = ", len(bldOO))
bldcount()
# Out:
# Number of patients with blood group A =  4
# Number of patients with blood group B =  3
# Number of patients with blood group AB =  1
# Number of patients with blood group O =  3
# Number of patients with blood group OO =  3

# %% [markdown]
# #Question 9
#
# a.) adding 6 + ‘a’ -   TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
#
#
#
# Referring to the 12th item of a list that has only 10
# items-                                                       IndexError: list index out of range
#
#
#
#
#
#
#
#     Using a value that is out of range for a function’s
# input, such as calling math.sqrt(-1.0)-                     IndexEror: function parameter out of range
#
#
#
#
#
#
#
#
# Using an undeclared variable, such as print(x)-          NameError: name 'x' is not defined
# when x has not been defined
#
#
#
#
#
#
#
#
# Trying to open a file that does not exist, such as
# mistyping the file name or looking in the wrong-           File not found
# directory.
